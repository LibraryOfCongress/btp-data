# %% [markdown]
# # Text tokenization
#
# This section contains code that will tokenize the transcription data and add new columns to the data frames for each transcription dataset.
#
# First, we run the definitions step from the previous section.

# %%
# %run 02_definitions.ipynb

# %% [markdown]
# ## Load each transcription dataset into a data frame
# The `load_csv` function will read the data from each path constant and store data in a Pandas data frame.

# %%
a = load_csv(ANTHONY)
c = load_csv(CATT)
s = load_csv(STANTON)
t = load_csv(TERRELL)

# %% [markdown]
# ### Optional: Preview the first five lines of a loaded dataset

# %% [markdown]
# #### Anthony

# %%
a.head()
# Out:
#                   Campaign                      Project  \
# 0  Susan B. Anthony Papers  Speeches and other writings
# 1  Susan B. Anthony Papers  Speeches and other writings
# 2  Susan B. Anthony Papers  Speeches and other writings
# 3  Susan B. Anthony Papers  Speeches and other writings
# 4  Susan B. Anthony Papers  Speeches and other writings
#
#                                                 Item       ItemId  \
# 0  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 1  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 2  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 3  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 4  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
#
#            Asset AssetId AssetStatus  \
# 0  mss11049038-1  179295   completed
# 1  mss11049038-2  179296   completed
# 2  mss11049038-3  179297   completed
# 3  mss11049038-4  179298   completed
# 4  mss11049038-5  179299   completed
#
#                                          DownloadUrl  \
# 0  http://tile.loc.gov/image-services/iiif/servic...
# 1  http://tile.loc.gov/image-services/iiif/servic...
# 2  http://tile.loc.gov/image-services/iiif/servic...
# 3  http://tile.loc.gov/image-services/iiif/servic...
# 4  http://tile.loc.gov/image-services/iiif/servic...
#
#                                        Transcription        Tags
# 0  Susan B. Anthony      SPEECHES AND WRITINGS FI...    May 1852
# 1  /52\r\nS.B.A-\r\n\r\nDelivered for the\r\nFirs...         NaN
# 2  will the best & wisest of mothers continue\r\n...  temperance
# 3  [Mind] the youthful mind.  Of how\r\nlittle av...  temperance
# 4  x\r\nWhile we labor to reclaim one generation ...  temperance

# %% [markdown]
# #### Catt

# %%
c.head()
# Out:
#                      Campaign                Project  \
# 0  Carrie Chapman Catt Papers  Speeches and articles
# 1  Carrie Chapman Catt Papers  Speeches and articles
# 2  Carrie Chapman Catt Papers  Speeches and articles
# 3  Carrie Chapman Catt Papers  Speeches and articles
# 4  Carrie Chapman Catt Papers  Speeches and articles
#
#                                                 Item        ItemId  \
# 0  Carrie Chapman Catt Papers: Speech and Article...  mss154040385
# 1  Carrie Chapman Catt Papers: Speech and Article...  mss154040385
# 2  Carrie Chapman Catt Papers: Speech and Article...  mss154040385
# 3  Carrie Chapman Catt Papers: Speech and Article...  mss154040386
# 4  Carrie Chapman Catt Papers: Speech and Article...  mss154040386
#
#             Asset AssetId AssetStatus  \
# 0  mss154040385-1  189284   completed
# 1  mss154040385-2  189285   completed
# 2  mss154040385-3  189286   completed
# 3  mss154040386-1  189287   completed
# 4  mss154040386-2  189288   completed
#
#                                          DownloadUrl  \
# 0  http://tile.loc.gov/image-services/iiif/servic...
# 1  http://tile.loc.gov/image-services/iiif/servic...
# 2  http://tile.loc.gov/image-services/iiif/servic...
# 3  http://tile.loc.gov/image-services/iiif/servic...
# 4  http://tile.loc.gov/image-services/iiif/servic...
#
#                                        Transcription Tags
# 0  CATT, Carrie Chapman\r\nSPEECH, ARTICLE, BOOK ...  NaN
# 1  -2-\r\nWe appeal in the name of our foremother...  NaN
# 2  AN APPEAL FOR LIBERTY.    1915\r\n\r\nBy Carri...  NaN
# 3  CATT, Carrie Chapman\r\nSPEECH, ARTICLE, BOOK ...  NaN
# 4  The \r\nWoman Citizen\r\nA WEEKLY CHRONICLE OF...  NaN

# %% [markdown]
# #### Stanton

# %%
s.head()
# Out:
#                         Campaign                 Project  \
# 0  Elizabeth Cady Stanton Papers  General correspondence
# 1  Elizabeth Cady Stanton Papers  General correspondence
# 2  Elizabeth Cady Stanton Papers  General correspondence
# 3  Elizabeth Cady Stanton Papers  General correspondence
# 4  Elizabeth Cady Stanton Papers  General correspondence
#
#                                                 Item        ItemId  \
# 0  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 1  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 2  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 3  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 4  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
#
#             Asset AssetId AssetStatus  \
# 0  mss412100001-1  179712   completed
# 1  mss412100001-2  179713   completed
# 2  mss412100001-3  179714   completed
# 3  mss412100001-4  179715   completed
# 4  mss412100001-5  179716   completed
#
#                                          DownloadUrl  \
# 0  http://tile.loc.gov/image-services/iiif/servic...
# 1  http://tile.loc.gov/image-services/iiif/servic...
# 2  http://tile.loc.gov/image-services/iiif/servic...
# 3  http://tile.loc.gov/image-services/iiif/servic...
# 4  http://tile.loc.gov/image-services/iiif/servic...
#
#                                        Transcription  \
# 0  Elizabeth Cady Stanton  GENERAL CORRESPONDENCE...
# 1  The following four letters are \r\nfrom Daniel...
# 2  22                                            ...
# 3  he could to make her respectable & happy. That...
# 4  Johnstown 2 D     Paid 10\r\n\r\n\r\nPeter Smi...
#
#                                    Tags
# 0                                   NaN
# 1  Peter Smith; Daniel Cady; Judge Cady
# 2                                   NaN
# 3                Peter Smith; Bonaparte
# 4                           Peter Smith

# %% [markdown]
# #### Terrell

# %%
t.head()
# Out:
#                                             Campaign  \
# 0  Mary Church Terrell: Advocate for African Amer...
# 1  Mary Church Terrell: Advocate for African Amer...
# 2  Mary Church Terrell: Advocate for African Amer...
# 3  Mary Church Terrell: Advocate for African Amer...
# 4  Mary Church Terrell: Advocate for African Amer...
#
#                          Project  \
# 0  Address and appointment books
# 1  Address and appointment books
# 2  Address and appointment books
# 3  Address and appointment books
# 4  Address and appointment books
#
#                                                 Item        ItemId  \
# 0  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 1  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 2  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 3  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 4  Mary Church Terrell Papers: Appointment Calend...  mss425490014
#
#             Asset AssetId AssetStatus  \
# 0  mss425490014-1    7580   completed
# 1  mss425490014-2    7581   completed
# 2  mss425490014-3    7582   completed
# 3  mss425490014-4    7583   completed
# 4  mss425490014-5    7584   completed
#
#                                          DownloadUrl  \
# 0  http://tile.loc.gov/image-services/iiif/servic...
# 1  http://tile.loc.gov/image-services/iiif/servic...
# 2  http://tile.loc.gov/image-services/iiif/servic...
# 3  http://tile.loc.gov/image-services/iiif/servic...
# 4  http://tile.loc.gov/image-services/iiif/servic...
#
#                                        Transcription  \
# 0  Office Supplies typewriter ribbons fountain pe...
# 1  March 16, Wednesday,1904 - Dr. Booker Washingt...
# 2  Fountain Pens Repaired\r\nTablets\r\nTypewrite...
# 3  May, 1904\r\n\r\n1 SUNDAY Received invitation ...
# 4  June, 1904\r\n\r\n7 TUESDAY Reached Bremer Hav...
#
#                                                 Tags
# 0  Mrs Ella Wheeler Wilcox; Woman Suffrage Conven...
# 1  Cruger; Calloway; VanRensselaer; Booker; Washi...
# 2           Pennsylvania; committee; Washington Post
# 3                                                NaN
# 4         Berlin; Congress morning; June 1904; Paris

# %% [markdown]
# ## Create a new column containing the output of the `tokens` function
# The `tokens` function uses the previously loaded spaCy model to analyze each word in the transcription. This results in several values for each word, including the lemma, the part-of-speech tag, the shape of the word, and whether it is a stop word or number.

# %%
# NOTE: This will take a while to run
for dataset in [a, c, s, t]:
    print(f"Tokenizing text for dataset: {dataset['Campaign'][0]}")
    dataset['tokenized_text'] = dataset['Transcription'].apply(tokens)
print("Done!")
# Out:
# Tokenizing text for dataset: Susan B. Anthony Papers
# Tokenizing text for dataset: Carrie Chapman Catt Papers
# Tokenizing text for dataset: Elizabeth Cady Stanton Papers
# Tokenizing text for dataset: Mary Church Terrell: Advocate for African Americans and Women
# Done!

# %% [markdown]
# ## Create a new column containing the output of the `entities` function
# The `entities` function uses the previously loaded spaCy model to identify persons, places, organizations, etc.

# %%
# NOTE: This will take a while to run
for dataset in [a, c, s, t]:
    print(f"Identifying entities for dataset: {dataset['Campaign'][0]}")
    dataset['entities'] = dataset['Transcription'].apply(entities)
print("Done!")
# Out:
# Identifying entities for dataset: Susan B. Anthony Papers
# Identifying entities for dataset: Carrie Chapman Catt Papers
# Identifying entities for dataset: Elizabeth Cady Stanton Papers
# Identifying entities for dataset: Mary Church Terrell: Advocate for African Americans and Women
# Done!

# %% [markdown]
# ### Optional: Preview the results of the `tokens` and `entities` functions for the first row of a dataset

# %% [markdown]
# #### Anthony

# %%
a.head(1)
a['tokenized_text'].iloc[0]
a['entities'].iloc[1000]
# Out:
# [('Wednesday, October 11, 1865', 0, 27, 'DATE'),
#  ('Auburn', 30, 36, 'GPE'),
#  ('P. Bridge', 40, 49, 'FAC'),
#  ('Wright', 79, 85, 'PERSON'),
#  ('Eliza\r\nWright Osbornes', 111, 133, 'PERSON'),
#  ('W.', 140, 142, 'PERSON'),
#  ("Woman's Rights", 166, 180, 'ORG'),
#  ('12 noon', 236, 243, 'TIME'),
#  ('Charles Mills', 255, 268, 'PERSON'),
#  ('Syracuse Depot', 273, 287, 'ORG'),
#  ('Sarah', 318, 323, 'PERSON'),
#  ('Thursday, October 12, 1865', 345, 371, 'DATE'),
#  ('Albany', 393, 399, 'GPE'),
#  ('Uncle & Aunt', 426, 438, 'ORG'),
#  ('2 P.M.', 452, 458, 'TIME'),
#  ('Albany', 471, 477, 'GPE'),
#  ('Phebe\r\n', 495, 502, 'PERSON'),
#  ('Margaret', 506, 514, 'PERSON'),
#  ('Lydia', 527, 532, 'PERSON'),
#  ('Jane', 537, 541, 'PERSON'),
#  ('Sister\r\nPhebe Willis', 551, 571, 'PERSON'),
#  ('tomorrow\r\nP.M.', 597, 611, 'DATE')]

# %% [markdown]
# #### Catt

# %%
c.head(1)
c['tokenized_text'].iloc[0]
c['entities'].iloc[1000]
# Out:
# [('English', 22, 29, 'LANGUAGE'),
#  ('60', 351, 353, 'CARDINAL'),
#  ('Parliament', 365, 375, 'ORG'),
#  ('a few \r\ndays ago', 413, 429, 'DATE'),
#  ('half-century', 503, 515, 'DATE'),
#  ('English', 581, 588, 'NORP'),
#  ('English', 1075, 1082, 'NORP'),
#  ('England', 1133, 1140, 'GPE'),
#  ('English', 1261, 1268, 'LANGUAGE'),
#  ('First', 1352, 1357, 'ORDINAL'),
#  ('English', 1446, 1453, 'LANGUAGE'),
#  ('English', 1603, 1610, 'NORP'),
#  ('Time', 1623, 1627, 'ORG'),
#  ('English', 2000, 2007, 'NORP'),
#  ('England', 2576, 2583, 'GPE'),
#  ('Houses of \r\nParliament', 2957, 2979, 'ORG'),
#  ('Parliament', 3159, 3169, 'ORG'),
#  ('Houses', 3300, 3306, 'ORG'),
#  ('Votes for Women', 3354, 3369, 'WORK_OF_ART'),
#  ('England', 3388, 3395, 'GPE'),
#  ('England', 3780, 3787, 'GPE'),
#  ('1215', 3859, 3863, 'CARDINAL'),
#  ('the Magna Charta', 4150, 4166, 'ORG'),
#  ('second', 4351, 4357, 'ORDINAL'),
#  ('English', 4380, 4387, 'LANGUAGE'),
#  ('one', 4596, 4599, 'CARDINAL'),
#  ('Nay', 4647, 4650, 'PERSON'),
#  ('English', 4665, 4672, 'LANGUAGE'),
#  ('the thirteenth century', 4742, 4764, 'DATE'),
#  ('English', 4813, 4820, 'NORP'),
#  ('the twentieth \r\ncentury', 4830, 4853, 'DATE'),
#  ('English', 5037, 5044, 'LANGUAGE'),
#  ('today', 5072, 5077, 'DATE'),
#  ('English', 5265, 5272, 'LANGUAGE'),
#  ('America', 5337, 5344, 'GPE'),
#  ('some decades', 5474, 5486, 'DATE'),
#  ('the United \r\nStates of America', 5625, 5655, 'GPE'),
#  ('the past 30 years', 5691, 5708, 'DATE'),
#  ('European', 6132, 6140, 'NORP'),
#  ('1848', 6155, 6159, 'DATE'),
#  ('the United States', 6297, 6314, 'GPE'),
#  ('the last century', 6352, 6368, 'DATE'),
#  ('the United States', 6466, 6483, 'GPE'),
#  ('Antagonists', 6539, 6550, 'PERSON'),
#  ('Success', 6834, 6841, 'ORG'),
#  ('the United States', 6887, 6904, 'GPE'),
#  ('today', 6976, 6981, 'DATE'),
#  ('the United States', 7128, 7145, 'GPE'),
#  ('150 years ago', 7429, 7442, 'DATE'),
#  ('Atlantic', 7484, 7492, 'LOC'),
#  ('today', 7561, 7566, 'DATE'),
#  ('Negroes', 7818, 7825, 'ORG'),
#  ('another million', 7833, 7848, 'CARDINAL'),
#  ('1,000,000', 7978, 7987, 'CARDINAL'),
#  ('each year', 7998, 8007, 'DATE'),
#  ('State', 8114, 8119, 'ORG'),
#  ('the United \r\nStates', 8317, 8336, 'GPE'),
#  ('the Rock of \r\nGibraltar', 8359, 8382, 'GPE'),
#  ('The Mississippi Dam', 8482, 8501, 'LOC'),
#  ('A few years ago', 8504, 8519, 'DATE'),
#  ('Mississippi', 8525, 8536, 'GPE'),
#  ('days', 8586, 8590, 'DATE'),
#  ('the Great \r\nRiver', 8837, 8854, 'EVENT'),
#  ('a mile', 8860, 8866, 'QUANTITY'),
#  ('the United States', 9003, 9020, 'GPE'),
#  ('7', 9389, 9390, 'CARDINAL')]

# %% [markdown]
# #### Stanton

# %%
s.head(1)
s['tokenized_text'].iloc[0]
s['entities'].iloc[1000]
# Out:
# [('2', 0, 1, 'CARDINAL'),
#  ('198', 4, 7, 'CARDINAL'),
#  ('342', 51, 54, 'CARDINAL'),
#  ('Nine', 131, 135, 'CARDINAL'),
#  ('the \r\nState', 223, 234, 'GPE'),
#  ('the State Constitution', 669, 691, 'LAW'),
#  ('250', 779, 782, 'MONEY'),
#  ('State', 938, 943, 'ORG'),
#  ('two', 1049, 1052, 'CARDINAL'),
#  ('one', 1269, 1272, 'CARDINAL'),
#  ('1898', 1483, 1487, 'DATE'),
#  ('English', 1539, 1546, 'LANGUAGE'),
#  ('State', 1613, 1618, 'ORG'),
#  ('hundreds every day', 1701, 1719, 'DATE'),
#  ('English', 1938, 1945, 'LANGUAGE'),
#  ('English', 2298, 2305, 'LANGUAGE'),
#  ('first', 2348, 2353, 'ORDINAL'),
#  ('some\r\nStates', 2490, 2502, 'GPE'),
#  ('at least two\r\nyears', 2703, 2722, 'CARDINAL'),
#  ('American', 3380, 3388, 'NORP'),
#  ('English', 3595, 3602, 'LANGUAGE'),
#  ('State', 4215, 4220, 'ORG'),
#  ('the New York State', 4332, 4350, 'ORG'),
#  ('the fiscal year ended\r\nJune 30th, 1894', 4400, 4438, 'DATE'),
#  ('288,020', 4440, 4447, 'CARDINAL'),
#  ('285,631', 4493, 4500, 'CARDINAL'),
#  ('2,389', 4517, 4522, 'CARDINAL'),
#  ('96,000', 4662, 4668, 'CARDINAL'),
#  ('New York State', 4688, 4702, 'GPE'),
#  ('42,000', 4704, 4710, 'CARDINAL'),
#  ('Pennsylvania', 4715, 4727, 'GPE'),
#  ('25,000', 4729, 4735, 'CARDINAL'),
#  ('Massachusetts', 4741, 4754, 'GPE'),
#  ('22,000', 4760, 4766, 'CARDINAL'),
#  ('Illinois', 4771, 4779, 'GPE'),
#  ('the United States', 4820, 4837, 'GPE'),
#  ('State', 4848, 4853, 'ORG'),
#  ('number than 10,000', 4875, 4893, 'CARDINAL'),
#  ('Southern States', 4922, 4937, 'LOC'),
#  ('12,000', 4965, 4971, 'CARDINAL'),
#  ('sixteen years of age', 4997, 5017, 'DATE'),
#  ('41,000', 5064, 5070, 'CARDINAL'),
#  ('every year', 5821, 5831, 'DATE'),
#  ('thousands', 6186, 6195, 'CARDINAL'),
#  ('Kansas', 6577, 6583, 'GPE'),
#  ('New York', 6588, 6596, 'GPE'),
#  ('Kansas', 6670, 6676, 'GPE'),
#  ('only 15,000', 6687, 6698, 'CARDINAL'),
#  ('30,000', 6753, 6759, 'CARDINAL'),
#  ('thousands', 6825, 6834, 'CARDINAL'),
#  ('first', 7005, 7010, 'ORDINAL'),
#  ('State', 7245, 7250, 'ORG'),
#  ('1', 7397, 7398, 'CARDINAL'),
#  ('2', 7437, 7438, 'CARDINAL'),
#  ('twenty-one', 7648, 7658, 'CARDINAL'),
#  ('3', 7664, 7665, 'CARDINAL'),
#  ('twenty-one', 7978, 7988, 'CARDINAL'),
#  ('English', 8053, 8060, 'LANGUAGE'),
#  ('1898', 8191, 8195, 'DATE'),
#  ('English', 8265, 8272, 'LANGUAGE'),
#  ('One', 8287, 8290, 'CARDINAL'),
#  ('our\r\nGovernment', 8450, 8465, 'ORG'),
#  ('New York', 8700, 8708, 'GPE'),
#  ('one', 9517, 9520, 'CARDINAL'),
#  ('first', 9771, 9776, 'ORDINAL'),
#  ('Our\r\nGovernment', 10092, 10107, 'ORG'),
#  ('State', 10835, 10840, 'ORG'),
#  ('Church', 10846, 10852, 'ORG'),
#  ('the Western States', 11246, 11264, 'GPE'),
#  ('Time', 11508, 11512, 'ORG'),
#  ('300,000', 11583, 11590, 'CARDINAL'),
#  ('English', 11780, 11787, 'LANGUAGE'),
#  ('State', 12958, 12963, 'ORG'),
#  ('one', 13241, 13244, 'CARDINAL'),
#  ('centuries', 13693, 13702, 'DATE'),
#  ('all these years', 13855, 13870, 'DATE'),
#  ('peans', 14541, 14546, 'PERSON'),
#  ('State', 14707, 14712, 'ORG'),
#  ('first', 14812, 14817, 'ORDINAL'),
#  ('State', 15189, 15194, 'ORG'),
#  ('Galton', 15852, 15858, 'PERSON'),
#  ('Heredity', 15875, 15883, 'ORG'),
#  ('a few\r\ndegrees', 16111, 16125, 'QUANTITY'),
#  ('Italy', 16469, 16474, 'GPE')]

# %% [markdown]
# #### Terrell

# %%
t.head(1)
t['tokenized_text'].iloc[0]
t['entities'].iloc[1000]
# Out:
# [('Star for Rosenwald Article', 11, 37, 'ORG'),
#  ('Mar 17-20\r\nApril\r\n5\r\nFriday', 38, 65, 'DATE'),
#  ('nearly 4', 73, 81, 'CARDINAL'),
#  ('Dawson', 111, 117, 'PERSON'),
#  ('Star', 138, 142, 'PRODUCT'),
#  ('Shirley\r\nGraham', 178, 193, 'PERSON'),
#  ('Bernard Mason', 198, 211, 'PERSON'),
#  ('Jernagins\r\nChurch', 215, 232, 'ORG'),
#  ('Graham', 239, 245, 'PERSON'),
#  ('Campbell Johnson', 266, 282, 'PERSON'),
#  ('S.W.\r\nCom House', 293, 308, 'ORG'),
#  ('Roberts', 321, 328, 'PERSON'),
#  ('Scott', 368, 373, 'PERSON'),
#  ('Roberts', 461, 468, 'PERSON'),
#  ('Felix Weir', 625, 635, 'PERSON'),
#  ('William', 689, 696, 'PERSON'),
#  ('Literary Agents', 810, 825, 'ORG'),
#  ('Friday', 828, 834, 'DATE'),
#  ('April  5', 837, 845, 'DATE'),
#  ('1935', 848, 852, 'DATE'),
#  ("Card Party Wests'", 856, 873, 'ORG'),
#  ('Park Rd Salon', 874, 887, 'FAC'),
#  ('Pk Rd N W', 892, 901, 'FAC'),
#  ('8 P.M.\r\nApril\r\n6\r\n', 902, 920, 'TIME'),
#  ('Hampton\r\nMary', 948, 961, 'PERSON'),
#  ('Hampton', 994, 1001, 'GPE'),
#  ('2nd', 1018, 1021, 'ORDINAL'),
#  ('Sunday         7           April', 1078, 1110, 'DATE'),
#  ('this morning', 1142, 1154, 'TIME'),
#  ('A. B Carrington', 1183, 1198, 'PERSON'),
#  ('Zion Wesley A.M.E Church', 1231, 1255, 'ORG'),
#  ('Monroe Trotter', 1293, 1307, 'PERSON'),
#  ('Paris', 1327, 1332, 'GPE'),
#  ('1919', 1336, 1340, 'DATE'),
#  ("the Women's International League of Peace &\r\nFreedom", 1373, 1425, 'ORG'),
#  ('Zurich', 1439, 1445, 'GPE'),
#  ('Trotter', 1455, 1462, 'PERSON'),
#  ('Paris', 1471, 1476, 'GPE'),
#  ('Paris', 1572, 1577, 'GPE'),
#  ('the Peace Conference', 1581, 1601, 'EVENT'),
#  ('U.S.', 1650, 1654, 'GPE')]

# %% [markdown]
# ## 2.3 Run the `separate_text` function to isolate tokens by category
#
# The `separate_text` function uses labels generated by the `spaCy` library to organize the contents of each transcription into actual text, stop words (conjunctions, prepositions, etc.), non-alphanumeric strings (punctuation, whitespace, etc.), numbers, and ambiguous words (when a transcriber cannot make out a word or character, a `?` will be used for the unknown character(s); this is reflected in the analyzed pattern of the word which is used to remove these words from the text category).

# %%
# Run the separate_text function on the Anthony data frame
for dataset in [a, c, s, t]:
    print(f"Organizing tokens by category for: {dataset['Campaign'][0]}")
    separate_text(dataset)
print("Done!")
# Out:
# Organizing tokens by category for: Susan B. Anthony Papers
# Organizing tokens by category for: Carrie Chapman Catt Papers
# Organizing tokens by category for: Elizabeth Cady Stanton Papers
# Organizing tokens by category for: Mary Church Terrell: Advocate for African Americans and Women
# Done!

# %% [markdown]
# ### Cache the result for next steps

# %%
for dataset in [a, c, s, t]:
    write_cache(dataset, str(dataset['Campaign'][0]))

# %% [markdown]
# ### Optional: Preview the results for the first six rows of the updated data frame

# %% [markdown]
# #### Anthony

# %%
a.iloc[0:6]
# Out:
#                   Campaign                      Project  \
# 0  Susan B. Anthony Papers  Speeches and other writings
# 1  Susan B. Anthony Papers  Speeches and other writings
# 2  Susan B. Anthony Papers  Speeches and other writings
# 3  Susan B. Anthony Papers  Speeches and other writings
# 4  Susan B. Anthony Papers  Speeches and other writings
# 5  Susan B. Anthony Papers  Speeches and other writings
#
#                                                 Item       ItemId  \
# 0  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 1  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 2  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 3  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 4  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
# 5  Susan B. Anthony Papers: Speeches and Writings...  mss11049038
#
#            Asset AssetId AssetStatus  \
# 0  mss11049038-1  179295   completed
# 1  mss11049038-2  179296   completed
# 2  mss11049038-3  179297   completed
# 3  mss11049038-4  179298   completed
# 4  mss11049038-5  179299   completed
# 5  mss11049038-6  179300   completed
#
#                                          DownloadUrl  \
# 0  http://tile.loc.gov/image-services/iiif/servic...
# 1  http://tile.loc.gov/image-services/iiif/servic...
# 2  http://tile.loc.gov/image-services/iiif/servic...
# 3  http://tile.loc.gov/image-services/iiif/servic...
# 4  http://tile.loc.gov/image-services/iiif/servic...
# 5  http://tile.loc.gov/image-services/iiif/servic...
#
#                                        Transcription        Tags  \
# 0  Susan B. Anthony      SPEECHES AND WRITINGS FI...    May 1852
# 1  /52\r\nS.B.A-\r\n\r\nDelivered for the\r\nFirs...         NaN
# 2  will the best & wisest of mothers continue\r\n...  temperance
# 3  [Mind] the youthful mind.  Of how\r\nlittle av...  temperance
# 4  x\r\nWhile we labor to reclaim one generation ...  temperance
# 5  Howard & their influence to help on the\r\nwor...  temperance
#
#                                       tokenized_text  \
# 0  [(Susan, Susan, PROPN, NNP, compound, Xxxxx, T...
# 1  [(/52, /52, PROPN, NNP, punct, /dd, False, Fal...
# 2  [(will, will, AUX, MD, aux, xxxx, True, True),...
# 3  [([, [, X, XX, dep, [, False, False), (Mind, m...
# 4  [(x, x, ADP, IN, punct, x, True, False), (\r\n...
# 5  [(Howard, Howard, PROPN, NNP, ROOT, Xxxxx, Tru...
#
#                                             entities  \
# 0  [(Susan B. Anthony      SPEECHES, 0, 30, PERSO...
# 1  [(Batavia, 44, 51, GPE), (N.J., 52, 56, GPE), ...
# 2  [(the\r\nSociety, 295, 307, ORG), (two, 324, 3...
# 3  [(christian, 77, 86, NORP), (truth  & sobernes...
# 4  [(one, 29, 32, CARDINAL), (Legislature, 145, 1...
# 5  [(Howard &, 0, 8, ORG), (State, 200, 205, ORG)...
#
#                                                 text  \
# 0  [(Susan, Susan, PROPN, NNP, compound, Xxxxx, T...
# 1  [(/52, /52, PROPN, NNP, punct, /dd, False, Fal...
# 2  [(best, good, ADJ, JJS, nsubj, xxxx, True, Fal...
# 3  [(Mind, mind, VERB, VB, dep, Xxxx, True, False...
# 4  [(x, x, ADP, IN, punct, x, True, False), (labo...
# 5  [(Howard, Howard, PROPN, NNP, ROOT, Xxxxx, Tru...
#
#                                           stop_words  \
# 0  [(AND, and, CCONJ, CC, cc, XXX, True, True), (...
# 1  [(for, for, ADP, IN, prep, xxx, True, True), (...
# 2  [(will, will, AUX, MD, aux, xxxx, True, True),...
# 3  [(the, the, DET, DT, det, xxx, True, True), (O...
# 4  [(While, while, SCONJ, IN, mark, Xxxxx, True, ...
# 5  [(their, their, PRON, PRP$, poss, xxxx, True, ...
#
#                                         nonalphanums  \
# 0  [(     ,      , SPACE, _SP, dep,     , False, ...
# 1  [(\r\n, \r\n, SPACE, _SP, dep, \r\n, False, Fa...
# 2  [(&, &, CCONJ, CC, cc, &, False, False), (\r\n...
# 3  [([, [, X, XX, dep, [, False, False), (], ], X...
# 4  [(\r\n, \r\n, SPACE, _SP, dep, \r\n, False, Fa...
# 5  [(&, &, CCONJ, CC, cc, &, False, False), (\r\n...
#
#                                              numbers ambigs  \
# 0  [(2, 2, NUM, CD, nummod, d, False, False), (18...     []
# 1  [(1852, 1852, NUM, CD, nummod, dddd, False, Fa...     []
# 2                                                 []     []
# 3                                                 []     []
# 4                                                 []     []
# 5  [(50, 50, NUM, CD, nummod, dd, False, False), ...     []
#
#                                       processed_text
# 0  [susan, b., anthony, speeches, writing, file, ...
# 1  [/52, s.b.a-, deliver, batavia, n.j., company,...
# 2  [good, wise, mother, continue, son, fall, vict...
# 3  [mind, youthful, mind, little, avail, untire, ...
# 4  [x, labor, reclaim, generation, drunkard, rise...
# 5  [howard, influence, help, work, lie, traffic, ...

# %% [markdown]
# #### Catt

# %%
c.iloc[0:6]
# Out:
#                      Campaign                Project  \
# 0  Carrie Chapman Catt Papers  Speeches and articles
# 1  Carrie Chapman Catt Papers  Speeches and articles
# 2  Carrie Chapman Catt Papers  Speeches and articles
# 3  Carrie Chapman Catt Papers  Speeches and articles
# 4  Carrie Chapman Catt Papers  Speeches and articles
# 5  Carrie Chapman Catt Papers  Speeches and articles
#
#                                                 Item        ItemId  \
# 0  Carrie Chapman Catt Papers: Speech and Article...  mss154040385
# 1  Carrie Chapman Catt Papers: Speech and Article...  mss154040385
# 2  Carrie Chapman Catt Papers: Speech and Article...  mss154040385
# 3  Carrie Chapman Catt Papers: Speech and Article...  mss154040386
# 4  Carrie Chapman Catt Papers: Speech and Article...  mss154040386
# 5  Carrie Chapman Catt Papers: Speech and Article...  mss154040386
#
#             Asset AssetId AssetStatus  \
# 0  mss154040385-1  189284   completed
# 1  mss154040385-2  189285   completed
# 2  mss154040385-3  189286   completed
# 3  mss154040386-1  189287   completed
# 4  mss154040386-2  189288   completed
# 5  mss154040386-3  189289   completed
#
#                                          DownloadUrl  \
# 0  http://tile.loc.gov/image-services/iiif/servic...
# 1  http://tile.loc.gov/image-services/iiif/servic...
# 2  http://tile.loc.gov/image-services/iiif/servic...
# 3  http://tile.loc.gov/image-services/iiif/servic...
# 4  http://tile.loc.gov/image-services/iiif/servic...
# 5  http://tile.loc.gov/image-services/iiif/servic...
#
#                                        Transcription Tags  \
# 0  CATT, Carrie Chapman\r\nSPEECH, ARTICLE, BOOK ...  NaN
# 1  -2-\r\nWe appeal in the name of our foremother...  NaN
# 2  AN APPEAL FOR LIBERTY.    1915\r\n\r\nBy Carri...  NaN
# 3  CATT, Carrie Chapman\r\nSPEECH, ARTICLE, BOOK ...  NaN
# 4  The \r\nWoman Citizen\r\nA WEEKLY CHRONICLE OF...  NaN
# 5  Eight Hundred and Eighty-six                  ...  NaN
#
#                                       tokenized_text  \
# 0  [(CATT, CATT, PROPN, NNP, ROOT, XXXX, True, Fa...
# 1  [(-2-, -2-, PUNCT, ``, punct, -d-, False, Fals...
# 2  [(AN, an, DET, DT, det, XX, True, True), (APPE...
# 3  [(CATT, CATT, PROPN, NNP, ROOT, XXXX, True, Fa...
# 4  [(The, the, DET, DT, det, Xxx, True, True), (\...
# 5  [(Eight, eight, NUM, CD, compound, Xxxxx, True...
#
#                                             entities  \
# 0  [(CATT, 0, 4, PERSON), (Carrie Chapman\r\nSPEE...
# 1  [(-2-\r\n, 0, 5, PERSON), (American, 428, 436,...
# 2  [(1915, 26, 30, DATE), (Carrie Chapman Catt, 3...
# 3  [(CATT, 0, 4, PERSON), (Carrie Chapman\r\nSPEE...
# 4  [(Carrie Chapman Catt, 156, 175, PERSON), (Con...
# 5  [(Eight Hundred and Eighty-six, 0, 28, CARDINA...
#
#                                                 text  \
# 0  [(CATT, CATT, PROPN, NNP, ROOT, XXXX, True, Fa...
# 1  [(appeal, appeal, VERB, VBP, ccomp, xxxx, True...
# 2  [(APPEAL, APPEAL, PROPN, NNP, ROOT, XXXX, True...
# 3  [(CATT, CATT, PROPN, NNP, ROOT, XXXX, True, Fa...
# 4  [(Woman, Woman, PROPN, NNP, compound, Xxxxx, T...
# 5  [(Woman, Woman, PROPN, NNP, nmod, Xxxxx, True,...
#
#                                           stop_words  \
# 0  [(An, an, DET, DT, det, Xx, True, True), (For,...
# 1  [(We, we, PRON, PRP, nsubj, Xx, True, True), (...
# 2  [(AN, an, DET, DT, det, XX, True, True), (FOR,...
# 3          [(Be, be, AUX, VB, ROOT, Xx, True, True)]
# 4  [(The, the, DET, DT, det, Xxx, True, True), (A...
# 5  [(Eight, eight, NUM, CD, compound, Xxxxx, True...
#
#                                         nonalphanums  \
# 0  [(,, ,, PUNCT, ,, punct, ,, False, False), (\r...
# 1  [(-2-, -2-, PUNCT, ``, punct, -d-, False, Fals...
# 2  [(., ., PUNCT, ., punct, ., False, False), (  ...
# 3  [(,, ,, PUNCT, ,, punct, ,, False, False), (\r...
# 4  [(\r\n, \r\n, SPACE, _SP, dep, \r\n, False, Fa...
# 5  [(-, -, PUNCT, HYPH, punct, -, False, False), ...
#
#                                              numbers ambigs  \
# 0                                                 []     []
# 1  [(1,600,000, 1,600,000, NUM, CD, nummod, d,ddd...     []
# 2  [(1915, 1915, NUM, CD, ROOT, dddd, False, Fals...     []
# 3                                                 []     []
# 4  [(21, 21, NUM, CD, nummod, dd, False, False), ...     []
# 5  [(Eighty, eighty, NUM, CD, compound, Xxxxx, Tr...     []
#
#                                       processed_text
# 0  [catt, carrie, chapman, speech, article, book,...
# 1  [appeal, foremother, forefather, equal, courag...
# 2  [appeal, liberty, carrie, chapman, catt, year,...
# 3  [catt, carrie, chapman, speech, article, book,...
# 4  [woman, citizen, weekly, chronicle, progress, ...
# 5  [woman, citizen, illinois, wisconsin, respecti...

# %% [markdown]
# #### Stanton

# %%
s.iloc[0:6]
# Out:
#                         Campaign                 Project  \
# 0  Elizabeth Cady Stanton Papers  General correspondence
# 1  Elizabeth Cady Stanton Papers  General correspondence
# 2  Elizabeth Cady Stanton Papers  General correspondence
# 3  Elizabeth Cady Stanton Papers  General correspondence
# 4  Elizabeth Cady Stanton Papers  General correspondence
# 5  Elizabeth Cady Stanton Papers  General correspondence
#
#                                                 Item        ItemId  \
# 0  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 1  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 2  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 3  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 4  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
# 5  Elizabeth Cady Stanton Papers: General Corresp...  mss412100001
#
#             Asset AssetId AssetStatus  \
# 0  mss412100001-1  179712   completed
# 1  mss412100001-2  179713   completed
# 2  mss412100001-3  179714   completed
# 3  mss412100001-4  179715   completed
# 4  mss412100001-5  179716   completed
# 5  mss412100001-6  179717   completed
#
#                                          DownloadUrl  \
# 0  http://tile.loc.gov/image-services/iiif/servic...
# 1  http://tile.loc.gov/image-services/iiif/servic...
# 2  http://tile.loc.gov/image-services/iiif/servic...
# 3  http://tile.loc.gov/image-services/iiif/servic...
# 4  http://tile.loc.gov/image-services/iiif/servic...
# 5  http://tile.loc.gov/image-services/iiif/servic...
#
#                                        Transcription  \
# 0  Elizabeth Cady Stanton  GENERAL CORRESPONDENCE...
# 1  The following four letters are \r\nfrom Daniel...
# 2  22                                            ...
# 3  he could to make her respectable & happy. That...
# 4  Johnstown 2 D     Paid 10\r\n\r\n\r\nPeter Smi...
# 5  23                                \r\nJohnstow...
#
#                                    Tags  \
# 0                                   NaN
# 1  Peter Smith; Daniel Cady; Judge Cady
# 2                                   NaN
# 3                Peter Smith; Bonaparte
# 4                           Peter Smith
# 5                                   NaN
#
#                                       tokenized_text  \
# 0  [(Elizabeth, Elizabeth, PROPN, NNP, compound, ...
# 1  [(The, the, DET, DT, det, Xxx, True, True), (f...
# 2  [(22, 22, NUM, CD, ROOT, dd, False, False), ( ...
# 3  [(he, he, PRON, PRP, nsubj, xx, True, True), (...
# 4  [(Johnstown, Johnstown, PROPN, NNP, nmod, Xxxx...
# 5  [(23, 23, NUM, CD, nummod, dd, False, False), ...
#
#                                             entities  \
# 0  [(Elizabeth Cady Stanton, 0, 22, PERSON), (181...
# 1  [(four, 14, 18, CARDINAL), (Daniel Cady, 38, 4...
# 2  [(22, 0, 2, CARDINAL), (2 Dec. 1814, 91, 102, ...
# 3  [(one, 467, 470, CARDINAL), (one, 614, 617, CA...
# 4  [(Johnstown, 0, 9, GPE), (10, 23, 25, CARDINAL...
# 5  [(23, 0, 2, CARDINAL), (October 1818, 50, 62, ...
#
#                                                 text  \
# 0  [(Elizabeth, Elizabeth, PROPN, NNP, compound, ...
# 1  [(following, follow, VERB, VBG, amod, xxxx, Tr...
# 2  [(Dec., Dec., PROPN, NNP, npadvmod, Xxx., Fals...
# 3  [(respectable, respectable, ADJ, JJ, ccomp, xx...
# 4  [(Johnstown, Johnstown, PROPN, NNP, nmod, Xxxx...
# 5  [(Johnstown, Johnstown, PROPN, NNP, compound, ...
#
#                                           stop_words  \
# 0                                                 []
# 1  [(The, the, DET, DT, det, Xxx, True, True), (f...
# 2  [(It, it, PRON, PRP, nsubj, Xx, True, True), (...
# 3  [(he, he, PRON, PRP, nsubj, xx, True, True), (...
# 4                                                 []
# 5  [(I, I, PRON, PRP, nsubj, X, True, True), (had...
#
#                                         nonalphanums  \
# 0  [( ,  , SPACE, _SP, dep,  , False, False), (-,...
# 1  [(\r\n, \r\n, SPACE, _SP, dep, \r\n, False, Fa...
# 2  [(                                            ...
# 3  [(&, &, CCONJ, CC, cc, &, False, False), (., ....
# 4  [(    ,     , SPACE, _SP, dep,     , False, Fa...
# 5  [(                               \r\n,        ...
#
#                                              numbers ambigs  \
# 0  [(1814, 1814, NUM, CD, appos, dddd, False, Fal...     []
# 1                                                 []     []
# 2  [(22, 22, NUM, CD, ROOT, dd, False, False), (2...     []
# 3  [(2d, 2d, NUM, CD, nummod, dx, False, False), ...     []
# 4  [(2, 2, NUM, CD, nummod, d, False, False), (10...     []
# 5  [(23, 23, NUM, CD, nummod, dd, False, False), ...     []
#
#                                       processed_text
# 0  [elizabeth, cady, stanton, general, correspond...
# 1  [follow, letter, daniel, cady, peter, smith, j...
# 2  [dec., dear, sir, true, lose, young, child, th...
# 3  [respectable, happy, moment, flatter, soon, se...
# 4  [johnstown, d, paid, peter, smith, esquire, pe...
# 5  [johnstown, 23d, october, dear, sir, fear, van...

# %% [markdown]
# #### Terrell

# %%
t.iloc[0:6]
# Out:
#                                             Campaign  \
# 0  Mary Church Terrell: Advocate for African Amer...
# 1  Mary Church Terrell: Advocate for African Amer...
# 2  Mary Church Terrell: Advocate for African Amer...
# 3  Mary Church Terrell: Advocate for African Amer...
# 4  Mary Church Terrell: Advocate for African Amer...
# 5  Mary Church Terrell: Advocate for African Amer...
#
#                          Project  \
# 0  Address and appointment books
# 1  Address and appointment books
# 2  Address and appointment books
# 3  Address and appointment books
# 4  Address and appointment books
# 5  Address and appointment books
#
#                                                 Item        ItemId  \
# 0  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 1  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 2  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 3  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 4  Mary Church Terrell Papers: Appointment Calend...  mss425490014
# 5  Mary Church Terrell Papers: Appointment Calend...  mss425490014
#
#             Asset AssetId AssetStatus  \
# 0  mss425490014-1    7580   completed
# 1  mss425490014-2    7581   completed
# 2  mss425490014-3    7582   completed
# 3  mss425490014-4    7583   completed
# 4  mss425490014-5    7584   completed
# 5  mss425490014-6    7585   completed
#
#                                          DownloadUrl  \
# 0  http://tile.loc.gov/image-services/iiif/servic...
# 1  http://tile.loc.gov/image-services/iiif/servic...
# 2  http://tile.loc.gov/image-services/iiif/servic...
# 3  http://tile.loc.gov/image-services/iiif/servic...
# 4  http://tile.loc.gov/image-services/iiif/servic...
# 5  http://tile.loc.gov/image-services/iiif/servic...
#
#                                        Transcription  \
# 0  Office Supplies typewriter ribbons fountain pe...
# 1  March 16, Wednesday,1904 - Dr. Booker Washingt...
# 2  Fountain Pens Repaired\r\nTablets\r\nTypewrite...
# 3  May, 1904\r\n\r\n1 SUNDAY Received invitation ...
# 4  June, 1904\r\n\r\n7 TUESDAY Reached Bremer Hav...
# 5  Swett's Blank Books Stationery \r\n603 Seventh...
#
#                                                 Tags  \
# 0  Mrs Ella Wheeler Wilcox; Woman Suffrage Conven...
# 1  Cruger; Calloway; VanRensselaer; Booker; Washi...
# 2           Pennsylvania; committee; Washington Post
# 3                                                NaN
# 4         Berlin; Congress morning; June 1904; Paris
# 5  Swett's Blank Books Stationery; Mr Stead; 603 ...
#
#                                       tokenized_text  \
# 0  [(Office, office, NOUN, NN, compound, Xxxxx, T...
# 1  [(March, March, PROPN, NNP, npadvmod, Xxxxx, T...
# 2  [(Fountain, Fountain, PROPN, NNP, compound, Xx...
# 3  [(May, May, PROPN, NNP, nmod, Xxx, True, True)...
# 4  [(June, June, PROPN, NNP, npadvmod, Xxxx, True...
# 5  [(Swett, Swett, PROPN, NNP, poss, Xxxxx, True,...
#
#                                             entities  \
# 0  [(Swett, 101, 106, PERSON), (Stationery Blank ...
# 1  [(March 16, 0, 8, DATE), (Booker, 31, 37, PERS...
# 2  [(Fountain Pens Repaired\r\nTablets\r\nTypewri...
# 3  [(May, 1904, 0, 9, DATE), (1, 13, 14, CARDINAL...
# 4  [(June, 1904, 0, 10, DATE), (7, 14, 15, CARDIN...
# 5  [(Swett, 0, 5, PERSON), (Blank Books Stationer...
#
#                                                 text  \
# 0  [(Office, office, NOUN, NN, compound, Xxxxx, T...
# 1  [(March, March, PROPN, NNP, npadvmod, Xxxxx, T...
# 2  [(Fountain, Fountain, PROPN, NNP, compound, Xx...
# 3  [(SUNDAY, SUNDAY, PROPN, NNP, appos, XXXX, Tru...
# 4  [(June, June, PROPN, NNP, npadvmod, Xxxx, True...
# 5  [(Swett, Swett, PROPN, NNP, poss, Xxxxx, True,...
#
#                                           stop_words  \
# 0  [(’s, ’s, PART, POS, case, ’x, False, True), (...
# 1  [(as, as, ADP, IN, prep, xx, True, True), (our...
# 2  [('s, 's, PART, POS, case, 'x, False, True), (...
# 3  [(May, May, PROPN, NNP, nmod, Xxx, True, True)...
# 4  [(in, in, ADP, IN, prep, xx, True, True), (at,...
# 5  [('s, 's, PART, POS, case, 'x, False, True), (...
#
#                                         nonalphanums  \
# 0  [(\r\n, \r\n, SPACE, _SP, dep, \r\n, False, Fa...
# 1  [(,, ,, PUNCT, ,, punct, ,, False, False), (-,...
# 2  [(\r\n, \r\n, SPACE, _SP, dep, \r\n, False, Fa...
# 3  [(,, ,, PUNCT, ,, punct, ,, False, False), (\r...
# 4  [(,, ,, PUNCT, ,, punct, ,, False, False), (\r...
# 5  [(\r\n, \r\n, SPACE, _SP, dep, \r\n, False, Fa...
#
#                                              numbers  \
# 0  [(603, 603, NUM, CD, nummod, ddd, False, False...
# 1  [(16, 16, NUM, CD, nummod, dd, False, False), ...
# 2  [(603, 603, NUM, CD, nummod, ddd, False, False...
# 3  [(1904, 1904, NUM, CD, nummod, dddd, False, Fa...
# 4  [(1904, 1904, NUM, CD, nummod, dddd, False, Fa...
# 5  [(603, 603, NUM, CD, nummod, ddd, False, False...
#
#                                               ambigs  \
# 0                                                 []
# 1                                                 []
# 2  [(?, ?, ADJ, JJ, punct, ?, False, False), (Wi?...
# 3                                                 []
# 4                                                 []
# 5          [(?, ?, NOUN, NN, nmod, ?, False, False)]
#
#                                       processed_text
# 0  [office, supply, typewriter, ribbon, fountain,...
# 1  [march, wednesday,1904, dr., booker, washingto...
# 2  [fountain, pens, repaired, tablet, typewriter,...
# 3  [sunday, receive, invitation, fran, olga, mr, ...
# 4  [june, tuesday, reach, bremer, haven, morning,...
# 5  [swett, blank, books, stationery, seventh, str...
